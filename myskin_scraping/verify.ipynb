# %%
import pandas as pd
path = "/Users/naruebet.orgl/Workspace/Labs/rnd_ai/myskin_scraping/raws/ALL_PRODUCTS_ULTRA_FAST_20250916_194921.csv"

# %%
df = pd.read_csv(path)
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                    name                                                url  \
# 0  Propyzamide Solution  https://www.myskinrecipes.com/shop/th/food-amp...
# 1                Pectin  https://www.myskinrecipes.com/shop/th/spectroq...
# 2       Docusate sodium  https://www.myskinrecipes.com/shop/th/pharmaco...
# 3          Fumonisin B2  https://www.myskinrecipes.com/shop/th/food-amp...
# 4             PRIMIDONE  https://www.myskinrecipes.com/shop/th/analytic...
#
#   price  original_price                                        description  \
# 0   NaN             NaN  สาร Propyzamide Solution ใช้เป็นสารกำจัดวัชพืช...
# 1   NaN             NaN  เพกตินถูกใช้เป็นสารทำให้เกิดเจลในอุตสาหกรรมอาห...
# 2   NaN             NaN  ใช้เป็นยาระบายอ่อนๆ ที่ช่วยให้อุจจาระนุ่มและเค...
# 3   NaN             NaN  ฟูมอนิซิน เบ2 เป็นไมโครท็อกซินที่เกิดจากเชื้อร...
# 4   NaN             NaN  ไพรมิโดนถูกใช้เป็นยารักษาโรคลมชักและอาการชัก โ...
#
# ...

# %%
df.tail()
# Out:
#                                               name  \
# 20808                        DL-1-Amino-2-propanol
# 20809  Isovaleraldehyde 2,4-Dinitrophenylhydrazone
# 20810          Sweet Orange Peel Oil (China, Sour)
# 20811                                      Taurine
# 20812          Magnesium Carbonate (24% Magnesium)
#
#                                                      url  \
# 20808  https://www.myskinrecipes.com/shop/th/food-amp...
# 20809  https://www.myskinrecipes.com/shop/th/analytic...
# 20810  https://www.myskinrecipes.com/shop/th/bergamot...
# 20811  https://www.myskinrecipes.com/shop/th/682-amin...
# 20812  https://www.myskinrecipes.com/shop/th/potassiu...
#
#                                                    price  original_price  \
# 20808                                                NaN             NaN
# 20809                                                NaN             NaN
# 20810  ฿35.00ราคาพิเศษนี้สำหรับสั่งหน้าเวปเท่านั้นราค...             NaN
# ...

# %%
df.shape
# Out:
# (20813, 44)

# %%
df.describe()
# Out:
#        original_price  rating  reviews_count            sku  dosage  \
# count             0.0     0.0            0.0   20813.000000     0.0
# mean              NaN     NaN            NaN  105937.798828     NaN
# std               NaN     NaN            NaN   76415.911452     NaN
# min               NaN     NaN            NaN       6.000000     NaN
# 25%               NaN     NaN            NaN   34417.000000     NaN
# 50%               NaN     NaN            NaN  101078.000000     NaN
# 75%               NaN     NaN            NaN  168807.000000     NaN
# max               NaN     NaN            NaN  253035.000000     NaN
#
#        mix_method  product_types  coa_specifications  usage_percent_lo  \
# count         0.0            0.0                 0.0      20210.000000
# mean          NaN            NaN                 NaN          0.665595
# std           NaN            NaN                 NaN          7.494076
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20813 entries, 0 to 20812
# Data columns (total 44 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   name                20813 non-null  object
#  1   url                 20813 non-null  object
#  2   price               6321 non-null   object
#  3   original_price      0 non-null      float64
#  4   description         19545 non-null  object
#  5   ingredients         2479 non-null   object
#  6   benefits            3974 non-null   object
#  7   usage               20210 non-null  object
#  8   images              20813 non-null  object
#  9   category            20813 non-null  object
#  10  subcategory         34 non-null     object
#  11  rating              0 non-null      float64
#  12  reviews_count       0 non-null      float64
#  13  availability        20813 non-null  object
#  14  sku                 20813 non-null  int64
# ...

# %%
print(df.benefits[1])
# Out:
# ['ในอุตสาหกรรมยา เพกตินใช้เป็นสารยึดติดในเม็ดยาหรือเป็นสารเคลือบเม็ดยา นอกจากนี้ยังมีการศึกษาเกี่ยวกับการใช้เพกตินในการควบคุมการปลดปล่อยยาในร่างกาย เนื่องจากสามารถบวมน้ำและสร้างชั้นเจลได้', 'เพกตินยังถูกนำมาใช้ในผลิตภัณฑ์ดูแลสุขภาพ เช่น อาหารเสริมที่ช่วยในการขับถ่ายหรือลดระดับคอเลสเตอรอล เนื่องจากมีคุณสมบัติเป็นไฟเบอร์ที่ละลายน้ำได้ และช่วยเพิ่มปริมาณอุจจาระ']

# %%
print(df.appearance[0])
# Out:
# ่ยงต่อการปนเปื้อนน้ำใต้ดิน และเหมาะสำหรับใช้ในระบบการเกษตรที่ต้องการควบคุมวัชพืชอย่างมีประสิทธิภาพโดยไม่ทำลายพืชหลัก

# %%
df.description[0:20]
# Out:
# 0     สาร Propyzamide Solution ใช้เป็นสารกำจัดวัชพืช...
# 1     เพกตินถูกใช้เป็นสารทำให้เกิดเจลในอุตสาหกรรมอาห...
# 2     ใช้เป็นยาระบายอ่อนๆ ที่ช่วยให้อุจจาระนุ่มและเค...
# 3     ฟูมอนิซิน เบ2 เป็นไมโครท็อกซินที่เกิดจากเชื้อร...
# 4     ไพรมิโดนถูกใช้เป็นยารักษาโรคลมชักและอาการชัก โ...
# 5     ซิลิโคน ชนิดพิเศษ ที่มีความบางเบาสูงสุด และระเ...
# 6     เดกซ์แทรนถูกนำมาใช้ในทางการแพทย์อย่างกว้างขวาง...
# 7     L-()-ฟรุกโตสเป็นน้ำตาลธรรมชาติที่พบในผลไม้และน...
# 8     ใช้เป็นสารตั้งต้นในการผลิตฟิโบรนิล ซึ่งเป็นสาร...
# 9     ไทเทเนียมไดออกไซด์ถูกใช้อย่างแพร่หลายในอุตสาหก...
# 10    Glucoamylase Enzyme (200,000U/g)\n\nGlucoamyla...
# 11    ซิลิโคนเจล เนื้อข้น สำหรับใช้เป็นเนื้อเจลเบส ใ...
# 12    เกรด อาหาร สามารถรับประทานได้﻿ ใช้ตกแต่งอาหาร\...
# 13                                                  NaN
# 14    สารนี้ใช้เป็นตัวเร่งปฏิกิริยาในกระบวนการสังเคร...
# 15                                                  NaN
# 16    ซิเตรทถูกนำมาใช้อย่างกว้างขวางในอุตสาหกรรมอาหา...
# ...

# %%
df.category[0:10]
# Out:
# 0                food amp cosmetic component standards
# 1    spectroquant photometry instruments kits amp a...
# 2    pharmacopeia amp metrological institutes stand...
# 3                food amp cosmetic component standards
# 4                            analytical chromatography
# 5                                silicone oil ระเหยได้
# 6                            analytical chromatography
# 7                                        carbohydrates
# 8                                  pesticide standards
# 9                                               metals
# Name: category, dtype: object

# %%
# Check null for all columns
df.isnull().sum()
# Out:
# name                      0
# url                       0
# price                 14492
# original_price        20813
# description            1268
# ingredients           18334
# benefits              16839
# usage                   603
# images                    0
# category                  0
# subcategory           20779
# rating                20813
# reviews_count         20813
# availability              0
# sku                       0
# tags                  16154
# detailed_info          1268
# mechanism             17780
# appearance             9715
# storage               16642
# shelf_life            17425
# dosage                20813
# recommended_dosage    11961
# mix_method            20813
# heat_resistance       16735
# ph_stability          19333
# solubility            10538
# product_types         20813
# inci_name             18144
# coa_specifications    20813
# sample_products       20531
# usage_percent_lo        603
# usage_percent_hi        603
# ...
