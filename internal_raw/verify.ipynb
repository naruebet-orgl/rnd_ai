# %%
import pandas as pd

path = "/Users/naruebet.orgl/Workspace/Labs/rnd_ai/internal_raw/formula_ingredients_data.csv"

# %%
pd.set_option('display.max_columns', None)
df = pd.read_csv(path)
# Out:
# /var/folders/_9/265g29r95n730k3qwnws2l380000gn/T/ipykernel_13379/2739277719.py:2: DtypeWarning: Columns (8,30,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
df.head()
# Out:
#    id rd_formula_id  rm_lines_id rmit_code  rmit_name rmit_trade_name  \
# 0   1    RDF2208001          NaN     Water        NaN           Water
# 1   2    RDF2208001          NaN  RC00Y001        NaN        Glycerin
# 2   3    RDF2208001          NaN  RC00R008        NaN   Radianol 4710
# 3   4    RDF2208001          NaN  RC00R001        NaN             HEC
# 4   5    RDF2208001          NaN  RC00H003        NaN       Oligo Hya
#
#            rmit_inci_name  master_formula supplier_code  supplier_name_th  \
# 0                   Water            85.4           NaN               NaN
# 1                Glycerin             1.0         SP001               NaN
# 2        Propylene glycol             3.0         SP001               NaN
# 3  Hydroxyethyl cellulose             2.0         SP002               NaN
# 4                     NaN             0.2         SP003               NaN
#
#   supplier_name_en  rm_price  rm_price_unit  rm_bulk_price  rm_bulk_price_bg  \
# ...
